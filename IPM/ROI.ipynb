# %%
# "left": 200,
# "right": 1750,
# "top": 900,
# "bottom": 1208

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("20181008095521_camera_frontcenter_000000595.png")
# cv2.imshow("Normal", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
for i in range(200-1, 1750-1):
    img[900-1][i] = (0, 0, 255)
    img[1208-3][i] = (0, 0, 255)
    img[900][i] = (0, 0, 255)
    img[1208-2][i] = (0, 0, 255)
    img[900+1][i] = (0, 0, 255)
    img[1208-1][i] = (0, 0, 255)

for i in range(900-1, 1208-1):
    img[i][200-1] = (0, 0, 255)
    img[i][1750-1] = (0, 0, 255)
    img[i][200] = (0, 0, 255)
    img[i][1750] = (0, 0, 255)
    img[i][200+1] = (0, 0, 255)
    img[i][1750+1] = (0, 0, 255)

# cv2.imshow("Normal", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
cv2.imwrite("NormalROI.png", img)
# Out:
# True
